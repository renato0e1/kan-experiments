# %% [markdown]
# # Aprendizado por Reforço Profundo baseado em Redes de Kolmogorov–Arnold: Uma Avaliação Experimental com LunarLander
# Implementação KKAN - Kurkova-Kolmogorov-Arnold: algoritmo DQN com buffer replay multistap aplicado ao ambiente LunarLander-v3.
#
# Autor: Renato França de Almeida - PPGEEC EMC/UFG

# %% [markdown]
# #1. Configurações iniciais

# %%
# !pip install ptflops
# !pip install sympy==1.12
# !pip install torchinfo
# !apt-get install -y swig cmake
# !pip install gymnasium
# !pip install "box2d@git+https://github.com/pybox2d/pybox2d.git"
# Out:
# Collecting ptflops
#   Downloading ptflops-0.7.5-py3-none-any.whl.metadata (9.4 kB)
# Requirement already satisfied: torch>=2.0 in /usr/local/lib/python3.12/dist-packages (from ptflops) (2.10.0+cu128)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch>=2.0->ptflops) (3.25.2)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0->ptflops) (4.15.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch>=2.0->ptflops) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0->ptflops) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0->ptflops) (3.6.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0->ptflops) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0->ptflops) (2025.3.0)
# Requirement already satisfied: cuda-bindings==12.9.4 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0->ptflops) (12.9.4)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.8.93 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0->ptflops) (12.8.93)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0->ptflops) (12.8.90)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0->ptflops) (12.8.90)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0->ptflops) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.8.4.1 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0->ptflops) (12.8.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.3.83 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0->ptflops) (11.3.3.83)
# Requirement already satisfied: nvidia-curand-cu12==10.3.9.90 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0->ptflops) (10.3.9.90)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.3.90 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0->ptflops) (11.7.3.90)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.8.93 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0->ptflops) (12.5.8.93)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0->ptflops) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.5 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0->ptflops) (2.27.5)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.4.5 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0->ptflops) (3.4.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0->ptflops) (12.8.90)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.8.93 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0->ptflops) (12.8.93)
# Requirement already satisfied: nvidia-cufile-cu12==1.13.1.3 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0->ptflops) (1.13.1.3)
# Requirement already satisfied: triton==3.6.0 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0->ptflops) (3.6.0)
# Requirement already satisfied: cuda-pathfinder~=1.1 in /usr/local/lib/python3.12/dist-packages (from cuda-bindings==12.9.4->torch>=2.0->ptflops) (1.5.2)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch>=2.0->ptflops) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch>=2.0->ptflops) (3.0.3)
# Downloading ptflops-0.7.5-py3-none-any.whl (19 kB)
# Installing collected packages: ptflops
# Successfully installed ptflops-0.7.5
# Collecting sympy==1.12
#   Downloading sympy-1.12-py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.12/dist-packages (from sympy==1.12) (1.3.0)
# Downloading sympy-1.12-py3-none-any.whl (5.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.7/5.7 MB 75.9 MB/s eta 0:00:00
# Installing collected packages: sympy
#   Attempting uninstall: sympy
#     Found existing installation: sympy 1.14.0
#     Uninstalling sympy-1.14.0:
#       Successfully uninstalled sympy-1.14.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# torch 2.10.0+cu128 requires sympy>=1.13.3, but you have sympy 1.12 which is incompatible.
# Successfully installed sympy-1.12
# Collecting torchinfo
#   Downloading torchinfo-1.8.0-py3-none-any.whl.metadata (21 kB)
# Downloading torchinfo-1.8.0-py3-none-any.whl (23 kB)
# Installing collected packages: torchinfo
# Successfully installed torchinfo-1.8.0
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# cmake is already the newest version (3.22.1-1ubuntu1.22.04.2).
# Suggested packages:
#   swig-doc swig-examples swig4.0-examples swig4.0-doc
# The following NEW packages will be installed:
#   swig swig4.0
# 0 upgraded, 2 newly installed, 0 to remove and 42 not upgraded.
# Need to get 1,116 kB of archives.
# After this operation, 5,542 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy/universe amd64 swig4.0 amd64 4.0.2-1ubuntu1 [1,110 kB]
# Get:2 http://archive.ubuntu.com/ubuntu jammy/universe amd64 swig all 4.0.2-1ubuntu1 [5,632 B]
# Fetched 1,116 kB in 1s (837 kB/s)
# Selecting previously unselected package swig4.0.
# (Reading database ... 122354 files and directories currently installed.)
# Preparing to unpack .../swig4.0_4.0.2-1ubuntu1_amd64.deb ...
# Unpacking swig4.0 (4.0.2-1ubuntu1) ...
# Selecting previously unselected package swig.
# Preparing to unpack .../swig_4.0.2-1ubuntu1_all.deb ...
# Unpacking swig (4.0.2-1ubuntu1) ...
# Setting up swig4.0 (4.0.2-1ubuntu1) ...
# Setting up swig (4.0.2-1ubuntu1) ...
# Processing triggers for man-db (2.10.2-1) ...
# Requirement already satisfied: gymnasium in /usr/local/lib/python3.12/dist-packages (1.2.3)
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.12/dist-packages (from gymnasium) (2.0.2)
# Requirement already satisfied: cloudpickle>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from gymnasium) (3.1.2)
# Requirement already satisfied: typing-extensions>=4.3.0 in /usr/local/lib/python3.12/dist-packages (from gymnasium) (4.15.0)
# Requirement already satisfied: farama-notifications>=0.0.1 in /usr/local/lib/python3.12/dist-packages (from gymnasium) (0.0.4)
# Collecting box2d@ git+https://github.com/pybox2d/pybox2d.git
#   Cloning https://github.com/pybox2d/pybox2d.git to /tmp/pip-install-hlp3wn3d/box2d_b6ef67de5e0340949eb89ff7b0223d60
#   Running command git clone --filter=blob:none --quiet https://github.com/pybox2d/pybox2d.git /tmp/pip-install-hlp3wn3d/box2d_b6ef67de5e0340949eb89ff7b0223d60
#   Resolved https://github.com/pybox2d/pybox2d.git to commit 09643321fd363f0850087d1bde8af3f4afd82163
#   Preparing metadata (setup.py) ... done
# Building wheels for collected packages: box2d
#   Building wheel for box2d (setup.py) ... done
#   Created wheel for box2d: filename=Box2D-2.3.10-cp312-cp312-linux_x86_64.whl size=3230621 sha256=62dbca30a9adc820267a27837b25a5bc391aa74d509f8f9abf0b4e7b6afcb919
#   Stored in directory: /tmp/pip-ephem-wheel-cache-3_gc_m1u/wheels/2c/ad/39/a80abfba30ebcec2f9ba76e2a8232b431a99dc2c67ee587d9f
# Successfully built box2d
# Installing collected packages: box2d
# Successfully installed box2d-2.3.10

# %% [markdown]
# #2. Importação

# %%
# Evitar erro de import circular
import os
os.environ['PYTORCH_JIT'] = '0'
os.environ['CUDA_LAUNCH_BLOCKING'] = '1'

# Ignorar alguns alertas
import warnings
warnings.filterwarnings("ignore", category=DeprecationWarning)
warnings.filterwarnings("ignore", message=".*std.*degrees of freedom.*")
warnings.filterwarnings("ignore", category=SyntaxWarning)
warnings.filterwarnings("ignore", category=UserWarning)

# Desabilita dynamo para evitar erro
try:
    torch._dynamo.config.suppress_errors = True
    torch._C._jit_set_profiling_executor(False)
    torch._C._jit_set_profiling_mode(False)
except:
    pass

import sympy
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import pytz
import copy
import gc
import random
import gymnasium as gym
import hashlib
import seaborn as sns
from time import time
from datetime import datetime
from collections import deque
from tqdm import tqdm, trange
from gymnasium.wrappers import RecordVideo
from IPython.display import Image, display, HTML
from base64 import b64encode
from ptflops import get_model_complexity_info
from torchinfo import summary
from google.colab import files

np.bool8 = np.bool_
matplotlib.use("Agg")
save_res = "resultados"
save_img = "img"
os.makedirs(save_res, exist_ok=True)
os.makedirs(save_img, exist_ok=True)

# %% [markdown]
# #3. Suporte

# %%
class Timer:
  def __init__(self):
    self.times = []
    self.sp_tz = pytz.timezone('America/Sao_Paulo')
    self.start()

  def start(self):
    self.tempo = time()
    print(f'({datetime.now(self.sp_tz).strftime("%H:%M:%S")}) Iniciou execução...')

  def stop(self):
    self.times.append(time() - self.tempo)
    print(f'({datetime.now(self.sp_tz).strftime("%H:%M:%S")}) Finalizou a execução em {self.times[-1]:.2f} segundos')

def get_hash_time():
  timestamp_float = time() # timestamp atual em segundos
  dado_para_hash = str(timestamp_float)
  dados_codificados = dado_para_hash.encode('utf-8')
  hash_objeto = hashlib.sha256(dados_codificados)
  hash_gerado = hash_objeto.hexdigest()[:10]
  return str(hash_gerado)

JANELA = 100

def plot_desempenho(rewards, best_reward, best_episode, janela=JANELA):
  """
  Dados de desempenho nos últimos 100 episodios
  """
  moving_avg = [np.mean(rewards[max(0, i-janela):i+1]) for i in range(len(rewards))]
  best_avg_idx = np.argmax(moving_avg)
  best_avg_value = moving_avg[best_avg_idx]
  last_100 = rewards[-janela:]
  last_100_mean = np.mean(last_100)
  last_100_std = np.std(last_100)
  if best_episode == 0:
      print("Nenhum modelo gerado por falta de performance...")
      return
  else:
    success_count = sum(1 for r in last_100 if r > 200)
    success_rate = (success_count / len(last_100)) * 100
    print(f"Desempenho:")
    print(f" Melhor resultado: {best_reward:.2f} (episódio {best_episode})")
    print(f" Melhor média ({janela} ep): {best_avg_value:.2f} (episódio {best_avg_idx+1})")
    print(f" Média últimos ({janela} ep): {last_100_mean:.2f} ± {last_100_std:.2f}")
    print(f" Taxa de sucesso (>200): {success_rate:.1f}% ({success_count}/100)")
    print("Conclusão:")
    if last_100_mean > 200:
        print(" SUCESSO! Agente RESOLVEU o ambiente!")
    elif last_100_mean > 100:
        print(" BOM! Agente próximo de resolver.")
    else:
        print(" Precisa de mais treinamento ou ajustes...")

def get_moving_avg(rewards, janela=JANELA):
  return [np.mean(rewards[max(0, i-janela):i+1]) for i in range(len(rewards))]

def plot_curva_aprendizado(rewards, save_img, figsize=(7,5)):
  """
  Curva de Aprendizado
  """
  moving_avg = get_moving_avg(rewards)
  plt.figure(figsize=figsize)
  plt.plot(rewards, alpha=0.3, color='blue')
  plt.plot(moving_avg, linewidth=2, color='red', label='Média 100')
  plt.axhline(y=200, color='green', linestyle='--', linewidth=2, label='Objetivo')
  plt.xlabel('Episódio')
  plt.ylabel('Recompensa')
  plt.title('Curva de Aprendizado')
  plt.legend()
  plt.grid(True, alpha=0.3)
  path_curva = f"{save_img}/curva_aprendizado.png"
  plt.savefig(path_curva, dpi=150)
  plt.show()
  plt.close()
  display(Image(filename=path_curva))

def plot_evolucao_desempenho(rewards, save_img, figsize=(7,5)):
  """
  Evolução do Desempenho (Média Móvel)
  """
  moving_avg = get_moving_avg(rewards)
  plt.figure(figsize=figsize)
  plt.plot(moving_avg, linewidth=2, color='orange')
  plt.axhline(y=200, color='green', linestyle='--', linewidth=2)
  plt.fill_between(range(len(moving_avg)), 0, moving_avg, alpha=0.3, color='orange')
  plt.xlabel('Episódio')
  plt.ylabel('Média Móvel')
  plt.title('Evolução do Desempenho')
  plt.grid(True, alpha=0.3)
  path_evolucao = f"{save_img}/evolucao_desempenho.png"
  plt.savefig(path_evolucao, dpi=150)
  plt.show()
  plt.close()
  display(Image(filename=path_evolucao))

def plot_distribuicao_recompensa(rewards, save_img, figsize=(7,5), janela=JANELA):
  """
  Distribuição da recompensa nos últimos 100 episodios
  """
  last_100 = rewards[-janela:]
  last_100_mean = np.mean(last_100)
  plt.figure(figsize=figsize)
  plt.hist(last_100, bins=30, alpha=0.7, color='purple', edgecolor='black')
  plt.axvline(last_100_mean, color='red', linestyle='--', linewidth=2, label=f'Média: {last_100_mean:.1f}')
  plt.axvline(200, color='green', linestyle='--', linewidth=2, label='Objetivo')
  plt.xlabel('Recompensa')
  plt.ylabel('Frequência')
  plt.title('Distribuição - Últimos 100 Ep')
  plt.legend()
  plt.grid(True, alpha=0.3)
  path_distribuicao = f"{save_img}/distribuicao_ultimos_100.png"
  plt.savefig(path_distribuicao, dpi=150)
  plt.show()
  plt.close()
  display(Image(filename=path_distribuicao))

def plot_distribuicao_segmento(rewards, save_img, figsize=(7,5)):
  """
  Distribuição por Segmento (Boxplot)
  """
  plt.figure(figsize=figsize)
  segments = [rewards[i:i+500] for i in range(0, len(rewards), 500)]
  plt.boxplot(segments, labels=[f'{i*500}-{(i+1)*500}' for i in range(len(segments))])
  plt.axhline(y=200, color='green', linestyle='--', linewidth=2)
  plt.xlabel('Segmento')
  plt.ylabel('Recompensa')
  plt.title('Distribuição por Segmento (Boxplot)')
  plt.grid(True, alpha=0.3)
  path_boxplot = f"{save_img}/distribuicao_segmento.png"
  plt.savefig(path_boxplot, dpi=150)
  plt.show()
  plt.close()
  display(Image(filename=path_boxplot))

def plot_losses(losses, save_img, figsize=(7,5)):
  # matplotlib.use("Agg")
  plt.figure(figsize=figsize)
  plt.plot(losses, linewidth=1, color='orange')
  plt.xlabel("Batch")
  plt.ylabel("Loss (média móvel)")
  plt.title("Média Móvel das Perdas")
  # plt.tight_layout()
  plt.grid(True, alpha=0.3)
  path_losses = f"{save_img}/losses.png"
  plt.savefig(path_losses, dpi=150)
  plt.show()
  plt.close()
  display(Image(filename=path_losses))

def plot_video(env, input_dim, hidden_layers, output_dim, gamma, save_res, nome_agente):
  print("Gravando vídeo do melhor agente...")
  device = "cuda" if torch.cuda.is_available() else "cpu"

  # Reconstrói o MESMO modelo usado no treino
  modelo = RLModelKKAN(
      input_dim=input_dim,
      internal_hidden=hidden_layers,
      cheb_degree=cheb_degree,
      output_dim=output_dim).to(device)

  # Carrega checkpoint
  checkpoint_path = os.path.join(save_res, nome_agente)
  checkpoint = torch.load(checkpoint_path, map_location=device)
  modelo.load_state_dict(checkpoint["model_state"])
  modelo.eval()

  # Cria agente APENAS para inferência
  dummy_optimizer = optim.Adam(modelo.parameters(), lr=1e-3)
  agent = Agente(modelo, dummy_optimizer, env, gamma, save_res)
  agent.epsilon = 0.0 # DESLIGA EXPLORAÇÃO

  # Ambiente com gravação
  video_dir = "videos"
  os.makedirs(video_dir, exist_ok=True)
  video_name = f"video-{get_hash_time()}"

  env_video = RecordVideo(
      gym.make(env.spec.id, render_mode="rgb_array"),
      video_folder=video_dir,
      name_prefix=video_name
  )

  # Executa episódio
  state, _ = env_video.reset()
  done = False
  total_reward = 0.0

  with torch.no_grad():
    while not done:
      action = agent.act(state)
      state, reward, terminated, truncated, _ = env_video.step(action)
      done = terminated or truncated
      total_reward += reward

  env_video.close()

  #  Exibe vídeo
  video_path = f"{video_dir}/{video_name}-episode-0.mp4"
  print(f"Agente carregado de: {checkpoint_path}")
  print(f"Vídeo gerado: {video_path}")
  print(f"Recompensa total: {total_reward:.2f}")
  mp4 = open(video_path, "rb").read()
  data_url = "data:video/mp4;base64," + b64encode(mp4).decode()

  return HTML(f"""
  <video width=600 controls>
      <source src="{data_url}" type="video/mp4">
  </video>
  """)

def plot_acoes_em_estado_critico(buffer, save_img, figsize=(7,5)):
  """
  Ações por Estado Crítico (pouso)
  """
  critical_actions = []
  for state, action, _, _, _ in buffer:
    x, y, vx, vy, angle, ang_vel, leg_l, leg_r = state
    if (y < 0.2) and (abs(vy) < 0.5) and (leg_l == 1 or leg_r == 1):
      critical_actions.append(action)
  if len(critical_actions) == 0:
    print("Nenhum estado crítico identificado.")
    return
  actions, counts = np.unique(critical_actions, return_counts=True)
  plt.figure(figsize=figsize)
  plt.bar(actions, counts)
  plt.xticks(actions)
  plt.xlabel("Ação")
  plt.ylabel("Frequência")
  plt.title("Ações em estados críticos de pouso")
  plt.grid(alpha=0.3)
  plt.tight_layout()
  save_path=f"{save_img}/acoes_estado_critico.png"
  plt.savefig(save_path, dpi=150)
  plt.show()
  display(Image(filename=save_path))

def plot_desvio_padrao_recompensa(rewards, save_img, figsize=(7,5), janela=JANELA):
  """
  Desvio Padrão da Recompensa (estabilidade)
  """
  rewards = np.array(rewards)
  rolling_std = [
      np.std(rewards[max(0, i - janela):i + 1])
      for i in range(len(rewards))
  ]
  plt.figure(figsize=figsize)
  plt.plot(rolling_std, label=f"Desvio padrão ({janela} ep.)", color="purple")
  plt.xlabel("Episódio")
  plt.ylabel("Desvio padrão da recompensa")
  plt.title("Estabilidade do aprendizado")
  plt.grid(alpha=0.3)
  plt.legend()
  plt.tight_layout()
  save_path=f"{save_img}/reward_std.png"
  plt.savefig(save_path, dpi=150)
  plt.show()
  display(Image(filename=save_path))

def plot_kkan_arquitetura(
    input_dim,
    hidden_layers,
    cheb_degree,
    output_dim,
    save_img,
    figsize=(9,5)):
    """
    Diagrama conceitual da arquitetura KKAN (Interno + Bases Chebyshev + Combinação externa)
    """

    #os.makedirs(save_img, exist_ok=True)
    fig, ax = plt.subplots(figsize=figsize)
    ax.axis("off")
    # Camadas reais (sem explodir Chebyshev)
    layers = [input_dim] + hidden_layers + [output_dim]
    labels = (
        ["Entrada"] +
        [f"Interna {i+1}" for i in range(len(hidden_layers))] +
        ["Saída / Ações"]
    )

    x_spacing = 2.2
    max_neurons = max(layers)
    x_positions = np.arange(len(layers)) * x_spacing

    # Plot neurônios normais
    for i, layer_size in enumerate(layers):
      y_positions = np.linspace(
          -layer_size/2,
          layer_size/2,
          layer_size)
      for y in y_positions:
        ax.plot(x_positions[i], y, "o", color="black")
      ax.text(
          x_positions[i],
          max_neurons/2 + 1,
          f"{labels[i]}\n({layer_size})",
          ha="center",
          fontsize=10,
          # weight="bold"
      )
      # Conexões densas só até saída
      if i < len(layers) - 1:
        next_size = layers[i+1]
        y_next = np.linspace(
            -next_size/2,
            next_size/2,
            next_size)
        for y1 in y_positions:
          for y2 in y_next:
            ax.plot(
                [x_positions[i], x_positions[i+1]],
                 [y1, y2],
                color="gray",
                alpha=0.08
                )

    # BLOCO CHEBYSHEV (funcional)
    cheb_x = x_positions[-2] + x_spacing/2

    rect = plt.Rectangle(
        (cheb_x - 0.4, -1.5),
        0.8,
        3.0,
        fill=False,
        edgecolor="darkred",
        linewidth=2
    )

    ax.add_patch(rect)

    ax.text(
        cheb_x,
        2.2,
        f"Bases Chebyshev\nGrau = {cheb_degree}\nExpansão:\nH × (D+1)",
        ha="center",
        fontsize=9,
        color="darkred",
    )

    # Conexão interno → Cheb
    ax.plot(
        [x_positions[-2], cheb_x - 0.4],
        [0, 0],
        color="darkred",
        linewidth=1.5
    )

    # Conexão Cheb → saída
    ax.plot(
        [cheb_x + 0.4, x_positions[-1]],
        [0, 0],
        color="darkred",
        linewidth=1.5
    )

    # Legenda
    ax.text(
        np.mean(x_positions),
        -max_neurons/2 - 2,
        "Arquitetura KKAN\nMLP Interno + Expansão Espectral Chebyshev + Combinação Linear",
        ha="center",
        fontsize=11,
    )

    plt.tight_layout()

    save_path = f"{save_img}/kkan_arquitetura.png"
    plt.savefig(save_path, dpi=150)
    plt.show()

    display(Image(filename=save_path))

# %% [markdown]
# #4. Classes e funções do negócio

# %% [markdown]
# ## Buffer

# %%
class BufferMultiStep:
  def __init__(self, capacity, n_step, gamma):
    self.capacity = capacity
    self.buffer = deque(maxlen=capacity)
    self.n_step = n_step
    self.gamma = gamma
    self.n_step_buffer = deque(maxlen=n_step)

  def add(self, state, action, reward, next_state, done):
    self.n_step_buffer.append((state, action, reward, next_state, done))
    if len(self.n_step_buffer) < self.n_step:
      return

    # Calcula recompensa n-step
    reward, next_state, done = self._get_n_step_info()
    state, action = self.n_step_buffer[0][:2]
    self.buffer.append((state, action, reward, next_state, done))

  def _get_n_step_info(self):
    reward, next_state, done = self.n_step_buffer[-1][-3:]
    for transition in reversed(list(self.n_step_buffer)[:-1]):
      r, n_s, d = transition[2:]
      d = bool(d)  # garante que é bool
      reward = r + self.gamma * reward * (1 - int(d))
      if d:
        next_state, done = n_s, d
    return reward, next_state, done

  def sample(self, batch_size):
    batch = random.sample(self.buffer, batch_size)
    states, actions, rewards, next_states, dones = zip(*batch)
    states = torch.from_numpy(np.array(states, dtype=np.float32))
    actions = torch.from_numpy(np.array(actions, dtype=np.int64))
    rewards = torch.from_numpy(np.array(rewards, dtype=np.float32))
    next_states = torch.from_numpy(np.array(next_states, dtype=np.float32))
    dones = torch.from_numpy(np.array(dones, dtype=np.float32))

    return states, actions, rewards, next_states, dones

  def __len__(self):
    return len(self.buffer)

# %% [markdown]
# ## Modelo KKAN

# %%
class ChebyshevLayer(nn.Module):
  """
  Camada de base Chebyshev
  """
  def __init__(self, in_features, degree):
    super().__init__()
    self.in_features = in_features
    self.degree = degree

  def forward(self, x):
    """
    x: (batch, in_features) assumindo que é normalizado em [-1, 1]
    """
    T0 = torch.ones_like(x)
    T1 = x
    cheb = [T0, T1]
    for n in range(2, self.degree + 1):
      Tn = 2 * x * cheb[-1] - cheb[-2]
      cheb.append(Tn)
    return torch.cat(cheb, dim=1)

# %%
class KKANInternalBlock(nn.Module):
  """
  Rede interna
  """
  def __init__(self, in_features, hidden_units):
    super().__init__()

    layers = []
    prev = in_features
    for h in hidden_units:
      layers.append(nn.Linear(prev, h))
      layers.append(nn.Tanh())
      prev = h

    self.rede = nn.Sequential(*layers)

  def forward(self, x):
    return self.rede(x)

class KKANExternalBlock(nn.Module):
  """
  Rede Externa - KKAN com base Chebyshev explícita
  """
  def __init__(self, in_features, degree, output_dim):
    super().__init__()
    self.cheb = ChebyshevLayer(in_features, degree)
    self.linear = nn.Linear(
        in_features * (degree + 1),
        output_dim,
        bias=False
    )
    # Escala residual (ssRBA-style)
    self.scale = nn.Parameter(torch.ones(output_dim))

  def forward(self, xi):
    """
    xi: [B, H] normalizado em [-1,1]
    """
    phi = self.cheb(xi) # [B, H*(D+1)]
    out = self.linear(phi) # [B, A]
    return self.scale * out

class RLModelKKAN(nn.Module):
  def __init__(self, input_dim, internal_hidden, cheb_degree, output_dim):
    super().__init__()
    # bloco interno
    self.inner = KKANInternalBlock(input_dim, internal_hidden)
    # bloco externo
    self.outer = KKANExternalBlock(
        in_features=internal_hidden[-1],
        degree=cheb_degree,
        output_dim=output_dim
    )

  def forward(self, x):
    # isso não é ativação é domínio funcional
    # x = torch.clamp(x, -1.0, 1.0)
    # xi = self.inner(x)
    # return self.outer(xi)
    x = torch.tanh(x) # domínio funcional suave
    xi = self.inner(x)
    xi = torch.tanh(xi)
    return self.outer(xi)

# %% [markdown]
# ## Agente

# %%
class Agente:
  def __init__(self, model, optimizer, env, gamma, save_dir, epsilon=1.0, epsilon_min=0.01, epsilon_decay=0.995):
    self.model = model
    self.optimizer = optimizer
    self.env = env
    self.gamma = gamma
    self.epsilon = epsilon
    self.epsilon_min = epsilon_min
    self.epsilon_decay = epsilon_decay
    self.losses = deque(maxlen=5000)
    self.loss_window = deque(maxlen=100)

    self.target_model = copy.deepcopy(model)
    self.target_model.eval()
    self.tau = 0.005 # Soft update

    self.loss_fn = nn.MSELoss()

  def soft_update(self):
    # for t, s in zip(self.target_model.parameters(), self.model.parameters()):
    #   t.data.copy_(self.tau * s.data + (1 - self.tau) * t.data)
    for target_param, param in zip(
        self.target_model.parameters(),
        self.model.parameters()):
        target_param.data.copy_(
            self.tau * param.data + (1.0 - self.tau) * target_param.data)

  def act(self, state):
    if np.random.rand() < self.epsilon:
      return random.randrange(self.env.action_space.n)
    state = torch.from_numpy(np.array(state, dtype=np.float32)).unsqueeze(0).to(next(self.model.parameters()).device)
    with torch.no_grad():
      q_values = self.model(state)
    return q_values.argmax().item()

  def remember_loss(self, loss_value):
    self.loss_window.append(loss_value)
    avg_loss = np.mean(self.loss_window)
    self.losses.append(avg_loss)

  def train(self, replay_buffer, batch_size, l1_lambda=0.0):
    # Amostra do replay buffer
    states, actions, rewards, next_states, dones = replay_buffer.sample(batch_size)

    states      = states.to(device)
    actions     = actions.to(device)
    rewards     = rewards.to(device)
    next_states = next_states.to(device)
    dones       = dones.to(device)

    # Q(s, a) atual
    q_values = self.model(states) # [B, A]
    q_sa = q_values.gather(1, actions.unsqueeze(1)) # [B, 1]
    q_sa = q_sa.squeeze(1) # [B]

    # Q_target = r + γ max Q'(s', a')
    with torch.no_grad():
      next_q_values = self.target_model(next_states) # [B, A]
      next_q = next_q_values.max(dim=1)[0] # [B]
      target = rewards + self.gamma * (1 - dones) * next_q

    # Loss TD
    loss = self.loss_fn(q_sa, target)

    # Regularização L1 (KKAN)
    if l1_lambda > 0:
      l1_penalty = 0.0
      for p in self.model.outer.parameters():
        l1_penalty += p.abs().sum()
      loss += l1_lambda * l1_penalty

    # Backpropagation
    self.optimizer.zero_grad()
    loss.backward()
    torch.nn.utils.clip_grad_norm_(self.model.parameters(), max_norm=1.0)
    self.optimizer.step()

    # registra loss
    self.remember_loss(loss.item())

    # Atualiza target network
    self.soft_update()

    return loss.item()

  def update_epsilon(self):
    self.epsilon = max(self.epsilon_min, self.epsilon * self.epsilon_decay)

  def save(self, filepath):
    """Salva modelo, otimizador e epsilon."""
    checkpoint = {
        "model_state": self.model.state_dict(),
        "optimizer_state": self.optimizer.state_dict(),
        "epsilon": self.epsilon
    }
    torch.save(checkpoint, filepath)
    print(f"Agente salvo em: {filepath}")

  def load(self, filepath, device="cpu"):
    """Carrega modelo, otimizador e epsilon."""
    checkpoint = torch.load(filepath, map_location=device)
    self.model.load_state_dict(checkpoint["model_state"], strict=False)
    # self.model.load_state_dict(checkpoint["model_state"])
    self.optimizer.load_state_dict(checkpoint["optimizer_state"])
    self.epsilon = checkpoint.get("epsilon", self.epsilon)
    self.model.to(device)
    print(f"Agente carregado de: {filepath}")

# %% [markdown]
# ## Processador

# %%
def run_experiment(
    env,
    agent,
    replay_buffer,
    num_episodes,
    batch_size,
    warmup_episodes,
    save_res,
    render=False,
):
  """
  Loop principal de treinamento do agente.
  Mostra recompensas em tempo real e salva checkpoints periodicamente.
  """
  nome_agente = ''
  rewards = []
  avg_rewards_10 = []
  avg_rewards_100 = []
  best_episode = 0
  best_reward = -float("inf")
  best_model_path = ''
  device = next(agent.model.parameters()).device
  print(f"Rodando na {device}")

  for episode in range(num_episodes):
    reset_output = env.reset()
    if isinstance(reset_output, tuple):
      state = reset_output[0]
    else:
      state = reset_output

    # state = np.tanh(state / 10)

    total_reward = 0
    done = False

    while not done:
      # Ação
      action = agent.act(state)

      # Passo do ambiente (compatível com gym e gymnasium)
      step_result = env.step(action)
      if len(step_result) == 5:
        next_state, reward, terminated, truncated, _ = step_result
        done = terminated or truncated
      else:
        next_state, reward, done, _ = step_result

      # Armazena no buffer
      replay_buffer.add(state, action, reward, next_state, done)
      state = next_state
      total_reward += reward

      # Treinamento
      if len(replay_buffer) > batch_size:
        agent.train(replay_buffer, batch_size) #, episode=episode, num_episodes=num_episodes)

      if render:
        env.render()

    # Atualiza epsilon
    agent.update_epsilon()

    # Estatísticas
    rewards.append(total_reward)
    avg_reward_10 = np.mean(rewards[-10:])
    avg_reward_100 = np.mean(rewards[-100:])
    avg_rewards_10.append(avg_reward_10)
    avg_rewards_100.append(avg_reward_100)

    warmup_status = " [WARMUP]" if episode < warmup_episodes else ""
    print(f"Ep {episode + 1:4d}/{num_episodes}{warmup_status} | "
          f"R: {total_reward:7.2f} | "
          f"Media10: {avg_reward_10:7.2f} | "
          f"Media100: {avg_reward_100:7.2f} | "
          f"eps: {agent.epsilon:.3f} | "
          f"Buf: {len(replay_buffer.buffer):6d}")

    # Salvando o melhor modelo
    if total_reward > 0 and total_reward > best_reward and episode > warmup_episodes:
      nome_agente = f"kkan_agente_{get_hash_time()}.pt"
      best_model_path = os.path.join(save_res, nome_agente)
      best_reward = total_reward
      best_episode = episode + 1
      agent.save(best_model_path)

  env.close()
  print(f"Treinamento finalizado com sucesso! Resultados salvos em: {best_model_path}")
  return nome_agente, rewards, avg_rewards_100, best_reward, best_episode

# %% [markdown]
# #5. Execução

# %%
# Parâmetros de Execução Otimizados
device = "cuda" if torch.cuda.is_available() else "cpu"
env_name = "LunarLander-v3"
num_episodes = 1700
capacity = 800000
batch_size = 16
n_step = 3
tau = 0.001
gamma = 0.99
lr = 5e-4
hidden_layers = [11, 11, 11]
warmup_episodes = 100
cheb_degree = 7 # grau das bases de Chebyshev
weight_decay = 1e-4

# Cria o ambiente
env = gym.make(env_name)

input_dim = env.observation_space.shape[0]
output_dim = env.action_space.n

# Configuração da rede KKAN
modelo = RLModelKKAN(
    input_dim=input_dim,
    internal_hidden=hidden_layers,
    cheb_degree=cheb_degree,
    output_dim=output_dim
).to(device)

# Inicializa otimizador, agente e buffer
optimizer = torch.optim.Adam(modelo.parameters(), lr, weight_decay=weight_decay)
agent = Agente(modelo, optimizer, env, gamma, save_res)
replay_buffer = BufferMultiStep(capacity, n_step, gamma)

# Executa o treinamento
timer = Timer()

nome_agente, rewards, avg_rewards, best_reward, best_episode = run_experiment(
    env,
    agent,
    replay_buffer,
    num_episodes,
    batch_size,
    warmup_episodes,
    save_res,
)
timer.stop()
# Out:
# (19:35:27) Iniciou execução...
# Rodando na cuda:0
# Ep    1/1700 [WARMUP] | R: -100.26 | Media10: -100.26 | Media100: -100.26 | eps: 0.995 | Buf:    110
# Ep    2/1700 [WARMUP] | R: -113.30 | Media10: -106.78 | Media100: -106.78 | eps: 0.990 | Buf:    192
# Ep    3/1700 [WARMUP] | R: -245.94 | Media10: -153.16 | Media100: -153.16 | eps: 0.985 | Buf:    314
# Ep    4/1700 [WARMUP] | R: -221.51 | Media10: -170.25 | Media100: -170.25 | eps: 0.980 | Buf:    429
# Ep    5/1700 [WARMUP] | R: -100.12 | Media10: -156.22 | Media100: -156.22 | eps: 0.975 | Buf:    529
# Ep    6/1700 [WARMUP] | R:  -32.86 | Media10: -135.66 | Media100: -135.66 | eps: 0.970 | Buf:    677
# Ep    7/1700 [WARMUP] | R: -219.63 | Media10: -147.66 | Media100: -147.66 | eps: 0.966 | Buf:    754
# Ep    8/1700 [WARMUP] | R:  -91.25 | Media10: -140.61 | Media100: -140.61 | eps: 0.961 | Buf:    860
# Ep    9/1700 [WARMUP] | R:  -88.12 | Media10: -134.78 | Media100: -134.78 | eps: 0.956 | Buf:    946
# Ep   10/1700 [WARMUP] | R:  -66.73 | Media10: -127.97 | Media100: -127.97 | eps: 0.951 | Buf:   1085
# Ep   35/1700 [WARMUP] | R:  -90.04 | Media10: -221.59 | Media100: -193.85 | eps: 0.839 | Buf:   3573
# Ep   36/1700 [WARMUP] | R: -307.73 | Media10: -245.45 | Media100: -197.02 | eps: 0.835 | Buf:   3698
# Ep   37/1700 [WARMUP] | R: -176.96 | Media10: -227.12 | Media100: -196.48 | eps: 0.831 | Buf:   3824
# Ep   38/1700 [WARMUP] | R: -136.22 | Media10: -229.29 | Media100: -194.89 | eps: 0.827 | Buf:   3899
# Ep   39/1700 [WARMUP] | R:  -66.86 | Media10: -227.17 | Media100: -191.61 | eps: 0.822 | Buf:   3984
# Ep   40/1700 [WARMUP] | R:  -83.23 | Media10: -188.78 | Media100: -188.90 | eps: 0.818 | Buf:   4052
# Ep   41/1700 [WARMUP] | R:  -10.04 | Media10: -170.05 | Media100: -184.53 | eps: 0.814 | Buf:   4164
# Ep   42/1700 [WARMUP] | R: -316.17 | Media10: -170.17 | Media100: -187.67 | eps: 0.810 | Buf:   4280
# Ep   43/1700 [WARMUP] | R: -139.12 | Media10: -143.48 | Media100: -186.54 | eps: 0.806 | Buf:   4385
# Ep   44/1700 [WARMUP] | R: -314.83 | Media10: -164.12 | Media100: -189.46 | eps: 0.802 | Buf:   4544
# Ep   45/1700 [WARMUP] | R:  -76.97 | Media10: -162.81 | Media100: -186.96 | eps: 0.798 | Buf:   4649
# Ep   46/1700 [WARMUP] | R:  -50.35 | Media10: -137.07 | Media100: -183.99 | eps: 0.794 | Buf:   4730
# Ep   47/1700 [WARMUP] | R: -114.51 | Media10: -130.83 | Media100: -182.51 | eps: 0.790 | Buf:   4822
# Ep   48/1700 [WARMUP] | R:  -76.36 | Media10: -124.84 | Media100: -180.30 | eps: 0.786 | Buf:   4921
# Ep   49/1700 [WARMUP] | R:  -74.78 | Media10: -125.64 | Media100: -178.14 | eps: 0.782 | Buf:   4993
# Ep   50/1700 [WARMUP] | R:  -49.31 | Media10: -122.24 | Media100: -175.57 | eps: 0.778 | Buf:   5062
# Ep   51/1700 [WARMUP] | R: -126.09 | Media10: -133.85 | Media100: -174.60 | eps: 0.774 | Buf:   5226
# Ep   52/1700 [WARMUP] | R:   -9.05 | Media10: -103.14 | Media100: -171.41 | eps: 0.771 | Buf:   5310
# Ep   53/1700 [WARMUP] | R: -137.64 | Media10: -102.99 | Media100: -170.78 | eps: 0.767 | Buf:   5389
# Ep   54/1700 [WARMUP] | R:  -45.22 | Media10:  -76.03 | Media100: -168.45 | eps: 0.763 | Buf:   5491
# Ep   55/1700 [WARMUP] | R: -139.92 | Media10:  -82.33 | Media100: -167.93 | eps: 0.759 | Buf:   5665
# Ep   56/1700 [WARMUP] | R:  -85.68 | Media10:  -85.86 | Media100: -166.46 | eps: 0.755 | Buf:   5749
# Ep   57/1700 [WARMUP] | R:  -68.37 | Media10:  -81.24 | Media100: -164.74 | eps: 0.751 | Buf:   5835
# Ep   58/1700 [WARMUP] | R:  -83.29 | Media10:  -81.94 | Media100: -163.34 | eps: 0.748 | Buf:   5916
# Ep 1689/1700 | R:  264.85 | Media10:  256.61 | Media100:  252.10 | eps: 0.010 | Buf: 800000
# Ep 1690/1700 | R:  249.91 | Media10:  255.82 | Media100:  252.00 | eps: 0.010 | Buf: 800000
# Ep 1691/1700 | R:  269.10 | Media10:  259.86 | Media100:  252.38 | eps: 0.010 | Buf: 800000
# Ep 1692/1700 | R:  229.85 | Media10:  256.05 | Media100:  252.16 | eps: 0.010 | Buf: 800000
# Ep 1693/1700 | R:  245.92 | Media10:  253.19 | Media100:  251.92 | eps: 0.010 | Buf: 800000
# Ep 1694/1700 | R:  276.81 | Media10:  256.48 | Media100:  252.40 | eps: 0.010 | Buf: 800000
# Ep 1695/1700 | R:  274.43 | Media10:  259.13 | Media100:  252.65 | eps: 0.010 | Buf: 800000
# Ep 1696/1700 | R:  252.14 | Media10:  260.42 | Media100:  252.42 | eps: 0.010 | Buf: 800000
# Ep 1697/1700 | R:  266.37 | Media10:  260.79 | Media100:  252.18 | eps: 0.010 | Buf: 800000
# Ep 1698/1700 | R:  270.28 | Media10:  259.97 | Media100:  252.61 | eps: 0.010 | Buf: 800000
# Ep 1699/1700 | R:  257.36 | Media10:  259.22 | Media100:  252.57 | eps: 0.010 | Buf: 800000
# Ep 1700/1700 | R:  290.38 | Media10:  263.26 | Media100:  253.26 | eps: 0.010 | Buf: 800000
# Treinamento finalizado com sucesso! Resultados salvos em: resultados/kkan_agente_e950d3f943.pt
# (21:27:50) Finalizou a execução em 6742.22 segundos

# %%
# download do melhor modelo
best_model_path = os.path.join(save_res, nome_agente)
files.download(f"{best_model_path}")
print(f"Download {best_model_path}")
# Out:
# Download resultados/kkan_agente_e950d3f943.pt

# %% [markdown]
# #6. Resultados

# %% [markdown]
# ## Desempenho

# %%
plot_desempenho(rewards, best_reward, best_episode)
# Out:
# Desempenho:
#  Melhor resultado: 295.45 (episódio 1637)
#  Melhor média (100 ep): 252.94 (episódio 1700)
#  Média últimos (100 ep): 253.26 ± 35.92
#  Taxa de sucesso (>200): 98.0% (98/100)
# Conclusão:
#  SUCESSO! Agente RESOLVEU o ambiente!

# %%
with torch.cuda.device(0):
  macs, params = get_model_complexity_info(
      modelo,
      (input_dim,),
      as_strings=True,
      print_per_layer_stat=True,
      verbose=True,
  )
print("FLOPs (MACs):", macs)
print("Parâmetros:", params)
# Out:
# Warning: module Tanh is treated as a zero-op.
# Warning: module KKANInternalBlock is treated as a zero-op.
# Warning: module ChebyshevLayer is treated as a zero-op.
# Warning: module KKANExternalBlock is treated as a zero-op.
# Warning: module RLModelKKAN is treated as a zero-op.
# RLModelKKAN(
#   715, 99.444% Params, 715.0 Mac, 100.000% MACs,
#   (inner): KKANInternalBlock(
#     363, 50.487% Params, 363.0 Mac, 50.769% MACs,
#     (rede): Sequential(
#       363, 50.487% Params, 363.0 Mac, 50.769% MACs,
#       (0): Linear(99, 13.769% Params, 99.0 Mac, 13.846% MACs, in_features=8, out_features=11, bias=True)
#       (1): Tanh(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#       (2): Linear(132, 18.359% Params, 132.0 Mac, 18.462% MACs, in_features=11, out_features=11, bias=True)
#       (3): Tanh(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#       (4): Linear(132, 18.359% Params, 132.0 Mac, 18.462% MACs, in_features=11, out_features=11, bias=True)
#       (5): Tanh(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#     )
#   )
#   (outer): KKANExternalBlock(
#     352, 48.957% Params, 352.0 Mac, 49.231% MACs,
#     (cheb): ChebyshevLayer(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#     (linear): Linear(352, 48.957% Params, 352.0 Mac, 49.231% MACs, in_features=88, out_features=4, bias=False)
#   )
# )
# FLOPs (MACs): 715 Mac
# Parâmetros: 719

# %% [markdown]
# ## Arquitetura da Rede

# %%
print(modelo)
# Out:
# RLModelKKAN(
#   (inner): KKANInternalBlock(
#     (rede): Sequential(
#       (0): Linear(in_features=8, out_features=11, bias=True)
#       (1): Tanh()
#       (2): Linear(in_features=11, out_features=11, bias=True)
#       (3): Tanh()
#       (4): Linear(in_features=11, out_features=11, bias=True)
#       (5): Tanh()
#     )
#   )
#   (outer): KKANExternalBlock(
#     (cheb): ChebyshevLayer()
#     (linear): Linear(in_features=88, out_features=4, bias=False)
#   )
# )

# %%
summary(modelo, input_size=(1, input_dim))
# Out:
# ==========================================================================================
# Layer (type:depth-idx)                   Output Shape              Param #
# ==========================================================================================
# RLModelKKAN                              [1, 4]                    --
# ├─KKANInternalBlock: 1-1                 [1, 11]                   --
# │    └─Sequential: 2-1                   [1, 11]                   --
# │    │    └─Linear: 3-1                  [1, 11]                   99
# │    │    └─Tanh: 3-2                    [1, 11]                   --
# │    │    └─Linear: 3-3                  [1, 11]                   132
# │    │    └─Tanh: 3-4                    [1, 11]                   --
# │    │    └─Linear: 3-5                  [1, 11]                   132
# │    │    └─Tanh: 3-6                    [1, 11]                   --
# ├─KKANExternalBlock: 1-2                 [1, 4]                    4
# │    └─ChebyshevLayer: 2-2               [1, 88]                   --
# │    └─Linear: 2-3                       [1, 4]                    352
# ==========================================================================================
# Total params: 719
# Trainable params: 719
# Non-trainable params: 0
# Total mult-adds (Units.MEGABYTES): 0.00
# ==========================================================================================
# Input size (MB): 0.00
# Forward/backward pass size (MB): 0.00
# Params size (MB): 0.00
# Estimated Total Size (MB): 0.00
# ==========================================================================================

# %%
plot_kkan_arquitetura(input_dim, hidden_layers, cheb_degree, output_dim, save_img)

# %% [markdown]
# ## Gráficos

# %%
plot_distribuicao_recompensa(rewards, save_img)

# %%
plot_curva_aprendizado(rewards, save_img)

# %%
plot_evolucao_desempenho(rewards, save_img)

# %%
plot_distribuicao_segmento(rewards, save_img)

# %%
plot_acoes_em_estado_critico(replay_buffer.buffer, save_img)

# %%
plot_desvio_padrao_recompensa(rewards, save_img)

# %%
plot_losses(agent.losses, save_img)

# %% [markdown]
# ##Vídeos

# %%
plot_video(env, input_dim, hidden_layers, output_dim, gamma, save_res, nome_agente)
# Out:
# Gravando vídeo do melhor agente...
# Agente carregado de: resultados/kkan_agente_e950d3f943.pt
# Vídeo gerado: videos/video-fbbea3aeb1-episode-0.mp4
# Recompensa total: 240.51
#   <video width=600 controls>
#       <source src="data:video/mp4;base64,..." type="video/mp4">
#   </video>

# %%
plot_video(env, input_dim, hidden_layers, output_dim, gamma, save_res, nome_agente)
# Out:
# Gravando vídeo do melhor agente...
# Agente carregado de: resultados/kkan_agente_e950d3f943.pt
# Vídeo gerado: videos/video-1c6d607886-episode-0.mp4
# Recompensa total: 263.80
#   <video width=600 controls>
#       <source src="data:video/mp4;base64,..." type="video/mp4">
#   </video>

# %%
plot_video(env, input_dim, hidden_layers, output_dim, gamma, save_res, nome_agente)
# Out:
# Gravando vídeo do melhor agente...
# Agente carregado de: resultados/kkan_agente_e950d3f943.pt
# Vídeo gerado: videos/video-8bcf8a4b5b-episode-0.mp4
# Recompensa total: 227.36
#   <video width=600 controls>
#       <source src="data:video/mp4;base64,..." type="video/mp4">
#   </video>

# %%
plot_video(env, input_dim, hidden_layers, output_dim, gamma, save_res, nome_agente)
# Out:
# Gravando vídeo do melhor agente...
# Agente carregado de: resultados/kkan_agente_e950d3f943.pt
# Vídeo gerado: videos/video-c201a729cf-episode-0.mp4
# Recompensa total: 222.85
#   <video width=600 controls>
#       <source src="data:video/mp4;base64,..." type="video/mp4">
#   </video>

# %%
plot_video(env, input_dim, hidden_layers, output_dim, gamma, save_res, nome_agente)
# Out:
# Gravando vídeo do melhor agente...
# Agente carregado de: resultados/kkan_agente_e950d3f943.pt
# Vídeo gerado: videos/video-de5ee6a4f7-episode-0.mp4
# Recompensa total: 239.39
#   <video width=600 controls>
#       <source src="data:video/mp4;base64,..." type="video/mp4">
#   </video>

# %%
plot_video(env, input_dim, hidden_layers, output_dim, gamma, save_res, nome_agente)
# Out:
# Gravando vídeo do melhor agente...
# Agente carregado de: resultados/kkan_agente_e950d3f943.pt
# Vídeo gerado: videos/video-4da32b4b33-episode-0.mp4
# Recompensa total: 248.86
#   <video width=600 controls>
#       <source src="data:video/mp4;base64,..." type="video/mp4">
#   </video>

# %%
plot_video(env, input_dim, hidden_layers, output_dim, gamma, save_res, nome_agente)
# Out:
# Gravando vídeo do melhor agente...
# Agente carregado de: resultados/kkan_agente_e950d3f943.pt
# Vídeo gerado: videos/video-9808988d26-episode-0.mp4
# Recompensa total: 266.66
#   <video width=600 controls>
#       <source src="data:video/mp4;base64,..." type="video/mp4">
#   </video>

# %%
plot_video(env, input_dim, hidden_layers, output_dim, gamma, save_res, nome_agente)
# Out:
# Gravando vídeo do melhor agente...
# Agente carregado de: resultados/kkan_agente_e950d3f943.pt
# Vídeo gerado: videos/video-ce3a455807-episode-0.mp4
# Recompensa total: 234.48
#   <video width=600 controls>
#       <source src="data:video/mp4;base64,..." type="video/mp4">
#   </video>

# %%
plot_video(env, input_dim, hidden_layers, output_dim, gamma, save_res, nome_agente)
# Out:
# Gravando vídeo do melhor agente...
# Agente carregado de: resultados/kkan_agente_e950d3f943.pt
# Vídeo gerado: videos/video-15305488f3-episode-0.mp4
# Recompensa total: -4.51
#   <video width=600 controls>
#       <source src="data:video/mp4;base64,..." type="video/mp4">
#   </video>
